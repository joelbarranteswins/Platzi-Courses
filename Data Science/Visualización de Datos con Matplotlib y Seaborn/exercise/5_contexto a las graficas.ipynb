# %% [markdown]
# Agreamos títulos, etiquetas, tamaños y leyendas para dar contexto y mejor información a las graficas

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0,5,11)
y = np.sin(x)

# %%
fig, axes = plt.subplots(1,2, figsize=(8,5))
axes[0].plot(x,y, label='$sin(x)$') # $ --> agrego la etiquta a modo de notación matematica
axes[0].set_title('Relación X - Y')
axes[0].set_xlabel('X')
axes[0].set_ylabel('Y')
axes[0].legend()

axes[1].plot(y,x, 'r') 
axes[1].set_title('Relación Y - X')
axes[1].set_xlabel('Y')
axes[1].set_ylabel('X')

#fig.tight_layout()
fig.show()
# Out:
# C:\Users\joel_\AppData\Local\Temp\ipykernel_7280\463129432.py:14: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
type(axes)
# Out:
# numpy.ndarray

# %% [markdown]
# Sin utilizar el metodo orientado a objetos

# %%
plt.plot(x,y, label='sin(x)')
plt.title('Titulo')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
