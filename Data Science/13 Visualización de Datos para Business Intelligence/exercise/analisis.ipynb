# %% [markdown]
# # Superstore dataset
#
# reponder las preguntas
#
# - ¿Cuál es la categoría de productos más vendida?
# - ¿Quién es el cliente que compra más?
# - ¿En qué Trimestre (Q) se realizan más ventas?

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel(
    './sample_superstore.xls',
    sheet_name='Orders'
)

# %%
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.to_csv('./superstore.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   datetime64[ns]
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
df.mean()
# Out:
# <ipython-input-6-c61f0c8f89b5>:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df.mean()
# Row ID          4997.500000
# Postal Code    55190.379428
# Sales            229.858001
# Quantity           3.789574
# Discount           0.156203
# Profit            28.656896
# dtype: float64

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.describe(include='all')
# Out:
# <ipython-input-8-174ba9bf1a5c>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df.describe(include='all')
# <ipython-input-8-174ba9bf1a5c>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df.describe(include='all')
#              Row ID        Order ID           Order Date            Ship Date  \
# count   9994.000000            9994                 9994                 9994
# unique          NaN            5009                 1237                 1334
# top             NaN  CA-2017-100111  2016-09-05 00:00:00  2015-12-16 00:00:00
# ...

# %%
df[['Category','Sales']]
# Out:
#              Category     Sales
# 0           Furniture  261.9600
# 1           Furniture  731.9400
# 2     Office Supplies   14.6200
# 3           Furniture  957.5775
# 4     Office Supplies   22.3680
# ...               ...       ...
# 9989        Furniture   25.2480
# 9990        Furniture   91.9600
# 9991       Technology  258.5760
# 9992  Office Supplies   29.6000
# 9993  Office Supplies  243.1600
#
# [9994 rows x 2 columns]

# %%
total_sales_category = df.groupby(['Category']).sum()
total_sales_category
# Out:
#                    Row ID  Postal Code        Sales  Quantity  Discount  \
# Category
# Furniture        10693326    118196026  741999.7953      8028    368.89
# Office Supplies  30010535    330772872  719047.0320     22906    947.80
# Technology        9241154    102603754  836154.0330      6939    244.40
#
#                       Profit
# Category
# Furniture         18451.2728
# Office Supplies  122490.8008
# Technology       145454.9481

# %%
# %matplotlib inline

# %%
list(total_sales_category.index)
# Out:
# ['Furniture', 'Office Supplies', 'Technology']

# %%
total_sales_category['Sales']
# Out:
# Category
# Furniture          741999.7953
# Office Supplies    719047.0320
# Technology         836154.0330
# Name: Sales, dtype: float64

# %%
total_sales_category.head()
# Out:
#                    Row ID  Postal Code        Sales  Quantity  Discount  \
# Category
# Furniture        10693326    118196026  741999.7953      8028    368.89
# Office Supplies  30010535    330772872  719047.0320     22906    947.80
# Technology        9241154    102603754  836154.0330      6939    244.40
#
#                       Profit
# Category
# Furniture         18451.2728
# Office Supplies  122490.8008
# Technology       145454.9481

# %%
list(total_sales_category['Sales'])
# Out:
# [741999.7952999998, 719047.0320000029, 836154.0329999966]

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.bar(
    total_sales_category.index,
    total_sales_category['Sales']
)
plt.show()

# %%
ax = sns.barplot(
    total_sales_category.index,
    total_sales_category['Sales']
)
# ax.set_yticklabels(['Alice', 'Bob', 'Bob'])
# ax.show()
# plt.show()
# Out:
# C:\Users\luisr\anaconda3\envs\data_science_ml\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df[['Customer ID', 'Quantity', 'Category']]
# Out:
#      Customer ID  Quantity         Category
# 0       CG-12520         2        Furniture
# 1       CG-12520         3        Furniture
# 2       DV-13045         2  Office Supplies
# 3       SO-20335         5        Furniture
# 4       SO-20335         2  Office Supplies
# ...          ...       ...              ...
# 9989    TB-21400         3        Furniture
# 9990    DB-13060         2        Furniture
# 9991    DB-13060         2       Technology
# 9992    DB-13060         4  Office Supplies
# 9993    CC-12220         2  Office Supplies
#
# [9994 rows x 3 columns]

# %%
df['ones'] = 1

# %%
df
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %%
df_customers = df.groupby(['Customer ID','Customer Name'])
df_customers

# %%
sorted_customers = df_customers.sum().sort_values('ones',ascending=False)

# %%
top_customers = sorted_customers[sorted_customers['ones'] > 29]
top_customers
# Out:
#                                  Row ID  Postal Code       Sales  Quantity  \
# Customer ID Customer Name
# WB-21850    William Brown        212661      2700341   6160.1020       146
# PP-18955    Paul Prost           141723      1369750   7252.6080       138
# JL-15835    John Lee             186361      1808244   9799.9230       143
# MA-17560    Matt Abelman         212304      1335854   4299.1610       117
# SV-20365    Seth Vernon          170128      1006579  11470.9500       109
# JD-15895    Jonathan Doherty     158582      1141398   7610.8640       150
# CK-12205    Chloris Kastensmidt  158526      1711979   3154.8550       122
# EH-13765    Edward Hooks         196975      1727018  10310.8800       120
# EP-13915    Emily Phan           161711      1884459   5478.0608       124
# ZC-21910    Zuschuss Carroll      92429      2318355   8025.7070       105
# AP-10915    Arthur Prichep       121433      2339139   3323.5560       102
# ...

# %%
list(top_customers.index)[:]
# Out:
# [('WB-21850', 'William Brown'),
#  ('PP-18955', 'Paul Prost'),
#  ('JL-15835', 'John Lee'),
#  ('MA-17560', 'Matt Abelman'),
#  ('SV-20365', 'Seth Vernon'),
#  ('JD-15895', 'Jonathan Doherty'),
#  ('CK-12205', 'Chloris Kastensmidt'),
#  ('EH-13765', 'Edward Hooks'),
#  ('EP-13915', 'Emily Phan'),
#  ('ZC-21910', 'Zuschuss Carroll'),
#  ('AP-10915', 'Arthur Prichep'),
#  ('LC-16870', 'Lena Cacioppo')]

# %%
customer_names = list(map(lambda x: x[1] , list(top_customers.index)))
customer_names
# Out:
# ['William Brown',
#  'Paul Prost',
#  'John Lee',
#  'Matt Abelman',
#  'Seth Vernon',
#  'Jonathan Doherty',
#  'Chloris Kastensmidt',
#  'Edward Hooks',
#  'Emily Phan',
#  'Zuschuss Carroll',
#  'Arthur Prichep',
#  'Lena Cacioppo']

# %%
plt.pie(top_customers['ones'], labels=customer_names)

plt.show()

# %%
customer_names[:5]
# Out:
# ['William Brown', 'Paul Prost', 'John Lee', 'Matt Abelman', 'Seth Vernon']

# %%
plt.pie(
    top_customers['ones'].head(5),
    labels=customer_names[:5]
)

plt.show()
# mostrar de esta forma el top 10 se aprecia poco la diferencia y el valor

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,2,2])

ax.barh(
    customer_names,
    top_customers['ones']
)
ax.invert_yaxis()
plt.show()
# se distingue mejor y se aprecian los valores

# %%
df_category_sales = df.groupby(['Customer ID','Customer Name', 'Category'])
df_category_sales = df_category_sales.sum()
df_category_sales.head()
# Out:
#                                            Row ID  Postal Code     Sales  \
# Customer ID Customer Name Category
# AA-10315    Alex Avila    Furniture          7470        10011    14.560
#                           Office Supplies   25950       560506  5075.304
#                           Technology        10403       157328   473.696
# AA-10375    Allen Armold  Furniture           808        68104    28.400
#                           Office Supplies   50269       487852   261.060
#
#                                            Quantity  Discount    Profit  ones
# Customer ID Customer Name Category
# AA-10315    Alex Avila    Furniture               2       0.0    6.2608     1
#                           Office Supplies        18       0.6 -407.2780     8
#                           Technology             10       0.4   38.1347     2
# AA-10375    Allen Armold  Furniture               2       0.0   11.0760     1
# ...

# %%
top_customers.head()
# Out:
#                            Row ID  Postal Code      Sales  Quantity  Discount  \
# Customer ID Customer Name
# WB-21850    William Brown  212661      2700341   6160.102       146       7.6
# PP-18955    Paul Prost     141723      1369750   7252.608       138       3.7
# JL-15835    John Lee       186361      1808244   9799.923       143       3.0
# MA-17560    Matt Abelman   212304      1335854   4299.161       117       3.2
# SV-20365    Seth Vernon    170128      1006579  11470.950       109       5.0
#
#                               Profit  ones
# Customer ID Customer Name
# WB-21850    William Brown   714.3311    37
# PP-18955    Paul Prost     1495.0854    34
# JL-15835    John Lee        228.9070    34
# MA-17560    Matt Abelman   1240.2266    34
# SV-20365    Seth Vernon    1199.4242    32

# %%
df_example = pd.DataFrame(columns=["App","Feature1", "Feature2","Feature3",
                           "Feature4","Feature5",
                           "Feature6","Feature7","Feature8"], 
                  data=[["SHA",0,0,1,1,1,0,1,0],
                        ["LHA",1,0,1,1,0,1,1,0],
                        ["DRA",0,0,0,0,0,0,1,0],
                        ["FRA",1,0,1,1,1,0,1,1],
                        ["BRU",0,0,1,0,1,0,0,0],
                        ["PAR",0,1,1,1,1,0,1,0],
                        ["AER",0,0,1,1,0,1,1,0],
                        ["SHE",0,0,0,1,0,0,1,0]])
df_example
# Out:
#    App  Feature1  Feature2  Feature3  Feature4  Feature5  Feature6  Feature7  \
# 0  SHA         0         0         1         1         1         0         1
# 1  LHA         1         0         1         1         0         1         1
# 2  DRA         0         0         0         0         0         0         1
# 3  FRA         1         0         1         1         1         0         1
# 4  BRU         0         0         1         0         1         0         0
# 5  PAR         0         1         1         1         1         0         1
# 6  AER         0         0         1         1         0         1         1
# 7  SHE         0         0         0         1         0         0         1
#
#    Feature8
# 0         0
# 1         0
# 2         0
# 3         1
# 4         0
# 5         0
# 6         0
# 7         0

# %%
df_category_sales.sort_values(['Customer ID', 'ones'], ascending=False)
# Out:
#                                                 Row ID  Postal Code     Sales  \
# Customer ID Customer Name      Category
# ZD-21925    Zuschuss Donatelli Office Supplies   12198       310470   108.704
#                                Technology         9734       173699  1297.400
#                                Furniture          8939        84795    87.840
# ZC-21910    Zuschuss Carroll   Office Supplies   57351      1315540  1819.645
#                                Furniture         24174       558337  3899.690
# ...                                                ...          ...       ...
# AA-10375    Allen Armold       Technology         9823       108457   766.930
#                                Furniture           808        68104    28.400
# AA-10315    Alex Avila         Office Supplies   25950       560506  5075.304
#                                Technology        10403       157328   473.696
# ...

# %%
df_category_sales.head()
# Out:
#                                            Row ID  Postal Code     Sales  \
# Customer ID Customer Name Category
# AA-10315    Alex Avila    Furniture          7470        10011    14.560
#                           Office Supplies   25950       560506  5075.304
#                           Technology        10403       157328   473.696
# AA-10375    Allen Armold  Furniture           808        68104    28.400
#                           Office Supplies   50269       487852   261.060
#
#                                            Quantity  Discount    Profit  ones
# Customer ID Customer Name Category
# AA-10315    Alex Avila    Furniture               2       0.0    6.2608     1
#                           Office Supplies        18       0.6 -407.2780     8
#                           Technology             10       0.4   38.1347     2
# AA-10375    Allen Armold  Furniture               2       0.0   11.0760     1
# ...

# %%
df_category_sales.groupby(level='Customer ID').transform('sum').loc[:, ('Quantity' ,'Profit','Sales','ones')]
# Out:
#                                                 Quantity     Profit     Sales  \
# Customer ID Customer Name      Category
# AA-10315    Alex Avila         Furniture              30  -362.8825  5563.560
#                                Office Supplies        30  -362.8825  5563.560
#                                Technology             30  -362.8825  5563.560
# AA-10375    Allen Armold       Furniture              41   277.3824  1056.390
#                                Office Supplies        41   277.3824  1056.390
# ...                                                  ...        ...       ...
# ZC-21910    Zuschuss Carroll   Office Supplies       105 -1032.1490  8025.707
#                                Technology            105 -1032.1490  8025.707
# ZD-21925    Zuschuss Donatelli Furniture              32   249.1307  1493.944
#                                Office Supplies        32   249.1307  1493.944
# ...

# %%
df_category_sales['t_ones'] = df_category_sales.groupby(level='Customer ID').transform('sum').loc[:, ('ones')]
df_category_sales['t_quantity'] = df_category_sales.groupby(level='Customer ID').transform('sum').loc[:, ('Quantity')]
df_category_sales['t_sales'] = df_category_sales.groupby(level='Customer ID').transform('sum').loc[:, ('Sales')]
df_category_sales['t_profit'] = df_category_sales.groupby(level='Customer ID').transform('sum').loc[:, ('Profit')]
df_category_sales
# Out:
#                                                 Row ID  Postal Code     Sales  \
# Customer ID Customer Name      Category
# AA-10315    Alex Avila         Furniture          7470        10011    14.560
#                                Office Supplies   25950       560506  5075.304
#                                Technology        10403       157328   473.696
# AA-10375    Allen Armold       Furniture           808        68104    28.400
#                                Office Supplies   50269       487852   261.060
# ...                                                ...          ...       ...
# ZC-21910    Zuschuss Carroll   Office Supplies   57351      1315540  1819.645
#                                Technology        10904       444478  2306.372
# ZD-21925    Zuschuss Donatelli Furniture          8939        84795    87.840
#                                Office Supplies   12198       310470   108.704
# ...

# %%
df_category_sales.max()
# Out:
# Row ID         1.597130e+05
# Postal Code    1.580813e+06
# Sales          2.348151e+04
# Quantity       1.150000e+02
# Discount       5.700000e+00
# Profit         8.584236e+03
# ones           2.600000e+01
# t_ones         3.700000e+01
# t_quantity     1.500000e+02
# t_sales        2.504305e+04
# t_profit       8.981324e+03
# dtype: float64

# %%
df_category_sales.min()
# Out:
# Row ID           36.0000
# Postal Code    1841.0000
# Sales             0.9900
# Quantity          1.0000
# Discount          0.0000
# Profit        -6397.9028
# ones              1.0000
# t_ones            1.0000
# t_quantity        2.0000
# t_sales           4.8330
# t_profit      -6626.3895
# dtype: float64

# %%
df.max()
# Out:
# Row ID                                         9994
# Order ID                             US-2017-169551
# Order Date                      2017-12-30 00:00:00
# Ship Date                       2018-01-05 00:00:00
# Ship Mode                            Standard Class
# Customer ID                                ZD-21925
# Customer Name                    Zuschuss Donatelli
# Segment                                 Home Office
# Country                               United States
# City                                           Yuma
# State                                       Wyoming
# Postal Code                                   99301
# Region                                         West
# Product ID                          TEC-PH-10004977
# Category                                 Technology
# Sub-Category                                 Tables
# Product Name     netTALK DUO VoIP Telephone Service
# Sales                                      22638.48
# ...

# %%
top_buyers = df_category_sales.sort_values(['t_ones', 'Customer ID'], ascending=False).head(32)
top_buyers
# Out:
#                                                  Row ID  Postal Code  \
# Customer ID Customer Name       Category
# WB-21850    William Brown       Furniture         39818       466888
#                                 Office Supplies  130923      1580813
#                                 Technology        41920       652640
# PP-18955    Paul Prost          Furniture         34822       402978
#                                 Office Supplies   75876       697067
#                                 Technology        31025       269705
# MA-17560    Matt Abelman        Furniture         46343       208770
#                                 Office Supplies  126740       814850
#                                 Technology        39221       312234
# JL-15835    John Lee            Furniture         40244       364334
#                                 Office Supplies  105964      1107355
#                                 Technology        40153       336555
# ...

# %%
top_buyers.isnull().values.any()
# Out:
# False

# %%
top_buyers['ones'].unstack()
# Out:
# Category                         Furniture  Office Supplies  Technology
# Customer ID Customer Name
# WB-21850    William Brown              6.0             23.0         8.0
# PP-18955    Paul Prost                 8.0             19.0         7.0
# MA-17560    Matt Abelman               6.0             21.0         7.0
# JL-15835    John Lee                   8.0             20.0         6.0
# SV-20365    Seth Vernon               15.0              9.0         8.0
# JD-15895    Jonathan Doherty           6.0             22.0         4.0
# EH-13765    Edward Hooks               6.0             26.0         NaN
# CK-12205    Chloris Kastensmidt        5.0             21.0         6.0
# ZC-21910    Zuschuss Carroll           8.0             17.0         6.0
# EP-13915    Emily Phan                 6.0             19.0         6.0
# AP-10915    Arthur Prichep             6.0             21.0         4.0

# %%
top_buyers['ones'].unstack().T
# Out:
# Customer ID          WB-21850   PP-18955     MA-17560 JL-15835    SV-20365  \
# Customer Name   William Brown Paul Prost Matt Abelman John Lee Seth Vernon
# Category
# Furniture                 6.0        8.0          6.0      8.0        15.0
# Office Supplies          23.0       19.0         21.0     20.0         9.0
# Technology                8.0        7.0          7.0      6.0         8.0
#
# Customer ID             JD-15895     EH-13765            CK-12205  \
# Customer Name   Jonathan Doherty Edward Hooks Chloris Kastensmidt
# Category
# Furniture                    6.0          6.0                 5.0
# Office Supplies             22.0         26.0                21.0
# Technology                   4.0          NaN                 6.0
#
# Customer ID             ZC-21910   EP-13915       AP-10915
# Customer Name   Zuschuss Carroll Emily Phan Arthur Prichep
# Category
# Furniture                    8.0        6.0            6.0
# ...

# %%
top_buyers['ones'].unstack().T.isnull().values.any()
# Out:
# True

# %%
top_buyers['ones'].unstack().T.loc['Technology'].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Customer ID,Customer Name'>

# %%
top_buyers['ones'].unstack().T.index
# Out:
# Index(['Furniture', 'Office Supplies', 'Technology'], dtype='object', name='Category')

# %%
top_buyers['ones'].unstack().index
# Out:
# MultiIndex([('WB-21850',       'William Brown'),
#             ('PP-18955',          'Paul Prost'),
#             ('MA-17560',        'Matt Abelman'),
#             ('JL-15835',            'John Lee'),
#             ('SV-20365',         'Seth Vernon'),
#             ('JD-15895',    'Jonathan Doherty'),
#             ('EH-13765',        'Edward Hooks'),
#             ('CK-12205', 'Chloris Kastensmidt'),
#             ('ZC-21910',    'Zuschuss Carroll'),
#             ('EP-13915',          'Emily Phan'),
#             ('AP-10915',      'Arthur Prichep')],
#            names=['Customer ID', 'Customer Name'])

# %%
buyers_names = list(map(lambda x: x[1] , list(top_buyers.unstack().index)))
buyers_names
# Out:
# ['William Brown',
#  'Paul Prost',
#  'Matt Abelman',
#  'John Lee',
#  'Seth Vernon',
#  'Jonathan Doherty',
#  'Edward Hooks',
#  'Chloris Kastensmidt',
#  'Zuschuss Carroll',
#  'Emily Phan',
#  'Arthur Prichep']

# %%
top_buyers['ones'].unstack().T.loc['Office Supplies']
# Out:
# Customer ID  Customer Name
# WB-21850     William Brown          23.0
# PP-18955     Paul Prost             19.0
# MA-17560     Matt Abelman           21.0
# JL-15835     John Lee               20.0
# SV-20365     Seth Vernon             9.0
# JD-15895     Jonathan Doherty       22.0
# EH-13765     Edward Hooks           26.0
# CK-12205     Chloris Kastensmidt    21.0
# ZC-21910     Zuschuss Carroll       17.0
# EP-13915     Emily Phan             19.0
# AP-10915     Arthur Prichep         21.0
# Name: Office Supplies, dtype: float64

# %%
 top_buyers[['ones']].unstack().T
# Out:
# Customer ID               WB-21850   PP-18955     MA-17560 JL-15835  \
# Customer Name        William Brown Paul Prost Matt Abelman John Lee
#      Category
# ones Furniture                 6.0        8.0          6.0      8.0
#      Office Supplies          23.0       19.0         21.0     20.0
#      Technology                8.0        7.0          7.0      6.0
#
# Customer ID             SV-20365         JD-15895     EH-13765  \
# Customer Name        Seth Vernon Jonathan Doherty Edward Hooks
#      Category
# ones Furniture              15.0              6.0          6.0
#      Office Supplies         9.0             22.0         26.0
#      Technology              8.0              4.0          NaN
#
# Customer ID                     CK-12205         ZC-21910   EP-13915  \
# Customer Name        Chloris Kastensmidt Zuschuss Carroll Emily Phan
#      Category
# ones Furniture                       5.0              8.0        6.0
# ...

# %%
plotting_data = top_buyers['ones'].unstack().T
plotting_data = plotting_data.fillna(0)
plotting_data
# Out:
# Customer ID          WB-21850   PP-18955     MA-17560 JL-15835    SV-20365  \
# Customer Name   William Brown Paul Prost Matt Abelman John Lee Seth Vernon
# Category
# Furniture                 6.0        8.0          6.0      8.0        15.0
# Office Supplies          23.0       19.0         21.0     20.0         9.0
# Technology                8.0        7.0          7.0      6.0         8.0
#
# Customer ID             JD-15895     EH-13765            CK-12205  \
# Customer Name   Jonathan Doherty Edward Hooks Chloris Kastensmidt
# Category
# Furniture                    6.0          6.0                 5.0
# Office Supplies             22.0         26.0                21.0
# Technology                   4.0          0.0                 6.0
#
# Customer ID             ZC-21910   EP-13915       AP-10915
# Customer Name   Zuschuss Carroll Emily Phan Arthur Prichep
# Category
# Furniture                    8.0        6.0            6.0
# ...

# %%
sns.set_context({"figure.figsize": (25, 10)})

furniturey = plotting_data.loc['Furniture']
officey = plotting_data.loc['Office Supplies']
techy = plotting_data.loc['Technology']

furniture_plot = sns.barplot(
    x = buyers_names,
    y = furniturey,
    color = "green",
)

office_plot = sns.barplot(
    x = buyers_names,
    y = officey,
    color = "blue",
    bottom= furniturey
)

tech_plot = sns.barplot(
    x = buyers_names,
    y = techy,
    color = "red",
    bottom= officey + furniturey # el bottom es extremadamente importante de otra forma , las graficas mas grandes tapan a las mas pequeñas ya que todas iniciarian desde el cero
)


sns.despine(left=True)
furniture_plot.set_ylabel("Sales")
furniture_plot.set_xlabel("Customers")

fbar = plt.Rectangle((0,0),1,1,fc='green',  edgecolor = 'none')
obar = plt.Rectangle((0,0),1,1,fc='blue',  edgecolor = 'none')
tbar = plt.Rectangle((0,0),1,1,fc="red", edgecolor = 'none')
l = plt.legend(
    [fbar, obar, tbar],
    [
        'Furniture',
        'Office Supplies',
        'Technology',
    ],
    loc=1,
    ncol = 3,
    prop={'size':12}
)
l.draw_frame(False)

for item in ([furniture_plot.xaxis.label, furniture_plot.yaxis.label] +
             furniture_plot.get_xticklabels() + furniture_plot.get_yticklabels()):
    item.set_fontsize(12)

# %%
# fig = plt.figure()

fig, ax = plt.subplots()

ax = fig.add_axes([0,0,1,1])
width = .5

ax.bar(
    buyers_names,
    furniturey,
    width,
    color = "green",
    label='Furniture'
)

ax.bar(
    buyers_names,
    officey,
    width,
    color = "blue",
    label='Office',
    bottom=furniturey
)

ax.bar(
    buyers_names,
    techy,
    width,
    color = "red",
    label='Technology',
    bottom=officey+furniturey
)

ax.set_ylabel('Sales')
ax.set_title('Customers')
ax.legend()
# ax.invert_yaxis()
plt.show()

# %%
# Out:
#                                    Row ID                             \
# Category                        Furniture Office Supplies Technology
# Customer ID Customer Name
# WB-21850    William Brown         39818.0        130923.0    41920.0
# PP-18955    Paul Prost            34822.0         75876.0    31025.0
# MA-17560    Matt Abelman          46343.0        126740.0    39221.0
# JL-15835    John Lee              40244.0        105964.0    40153.0
# SV-20365    Seth Vernon           72799.0         54715.0    42614.0
# JD-15895    Jonathan Doherty      21987.0        116910.0    19685.0
# EH-13765    Edward Hooks          37262.0        159713.0        NaN
# CK-12205    Chloris Kastensmidt   25624.0        104117.0    28785.0
# ZC-21910    Zuschuss Carroll      24174.0         57351.0    10904.0
# EP-13915    Emily Phan            27303.0        110277.0    24131.0
# AP-10915    Arthur Prichep        25988.0             NaN        NaN
#
# ...

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit', 'ones'],
#       dtype='object')
